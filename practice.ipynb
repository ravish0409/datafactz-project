# %% [markdown]
# # pandas

# %% [markdown]
# Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Dataset

# %%
df=pd.read_csv("5000 Sales Records.csv")
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# load 5 rows

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Indexing and Selection

# %% [markdown]
# select single column

# %%
df["Item Type"]
# Out:
# 0       Baby Food
# 1          Snacks
# 2       Beverages
# 3          Cereal
# 4          Snacks
#           ...
# 4994    Cosmetics
# 4995    Household
# 4996      Clothes
# 4997    Baby Food
# 4998      Clothes
# Name: Item Type, Length: 4999, dtype: object

# %% [markdown]
# select multiple columns

# %%
df[['Region', 'Country', 'Sales Channel']]
# Out:
#                                  Region               Country Sales Channel
# 0     Central America and the Caribbean  Antigua and Barbuda         Online
# 1     Central America and the Caribbean                Panama       Offline
# 2                                Europe        Czech Republic       Offline
# 3                                  Asia           North Korea       Offline
# 4                                  Asia             Sri Lanka       Offline
# ...                                 ...                   ...           ...
# 4994                 Sub-Saharan Africa               Liberia       Offline
# 4995              Australia and Oceania           New Zealand       Offline
# 4996       Middle East and North Africa            Azerbaijan       Offline
# 4997                               Asia               Myanmar       Offline
# 4998                             Europe               Finland        Online
#
# [4999 rows x 3 columns]

# %% [markdown]
# Select a row by its index label

# %%
df.loc[0]
# Out:
# Region            Central America and the Caribbean
# Country                        Antigua and Barbuda
# Item Type                                 Baby Food
# Sales Channel                                Online
# Order Priority                                    M
# Order Date                               12/20/2013
# Order ID                                  957081544
# Ship Date                                 1/11/2014
# Units Sold                                      552
# Unit Price                                   255.28
# Unit Cost                                    159.42
# Total Revenue                             140914.56
# Total Cost                                 87999.84
# Total Profit                               52914.72
# Name: 0, dtype: object

# %% [markdown]
# Select multiple rows by index

# %%
df.loc[[0, 1, 2]]
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42      140914.56    87999.84      52914.72
# 1      152.58      97.44      330640.86   211152.48     119488.38
# 2       47.45      31.79      226716.10   151892.62      74823.48

# %% [markdown]
# ### Boolean Indexing

# %% [markdown]
# select rows where 'Sales Channel' is 'Online'

# %%
df[df['Sales Channel'] == 'Online']
# Out:
#                                  Region                           Country  \
# 0     Central America and the Caribbean              Antigua and Barbuda
# 7                                Europe            Bosnia and Herzegovina
# 9                    Sub-Saharan Africa                          Ethiopia
# 11         Middle East and North Africa                              Oman
# 14    Central America and the Caribbean  Saint Vincent and the Grenadines
# ...                                 ...                               ...
# 4983                               Asia                       South Korea
# 4986                               Asia                         Sri Lanka
# 4988       Middle East and North Africa              United Arab Emirates
# 4989                               Asia                          Thailand
# 4998                             Europe                           Finland
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %% [markdown]
# Select rows where 'Units Sold' is greater than 500

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# ## converting columns to float data type

# %%
numeric_columns = ['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
df
# Out:
#                                  Region               Country  Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean                Panama     Snacks
# 2                                Europe        Czech Republic  Beverages
# 3                                  Asia           North Korea     Cereal
# 4                                  Asia             Sri Lanka     Snacks
# ...                                 ...                   ...        ...
# 4994                 Sub-Saharan Africa               Liberia  Cosmetics
# 4995              Australia and Oceania           New Zealand  Household
# 4996       Middle East and North Africa            Azerbaijan    Clothes
# 4997                               Asia               Myanmar  Baby Food
# 4998                             Europe               Finland    Clothes
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          4999 non-null   object
#  1   Country         4999 non-null   object
#  2   Item Type       4999 non-null   object
#  3   Sales Channel   4999 non-null   object
#  4   Order Priority  4999 non-null   object
#  5   Order Date      4999 non-null   object
#  6   Order ID        4999 non-null   int64
#  7   Ship Date       4999 non-null   object
#  8   Units Sold      4999 non-null   int64
#  9   Unit Price      4999 non-null   float64
#  10  Unit Cost       4999 non-null   float64
#  11  Total Revenue   4999 non-null   float64
#  12  Total Cost      4999 non-null   float64
#  13  Total Profit    4999 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 546.9+ KB

# %%
df.tail()
# Out:
#                             Region      Country  Item Type Sales Channel  \
# 4994            Sub-Saharan Africa      Liberia  Cosmetics       Offline
# 4995         Australia and Oceania  New Zealand  Household       Offline
# 4996  Middle East and North Africa   Azerbaijan    Clothes       Offline
# 4997                          Asia      Myanmar  Baby Food       Offline
# 4998                        Europe      Finland    Clothes        Online
#
#      Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 4994              M   6/17/2012  374724614   6/23/2012        8195
# 4995              C    4/3/2015  217984473   4/20/2015        5305
# 4996              L   8/17/2014  169748055   10/2/2014        1077
# 4997              H  11/23/2016  226939189  12/10/2016        5204
# 4998              L   4/22/2014  906794202   5/11/2014        9410
#
#       Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# Select rows where 'Units Sold' is greater than 9990

# %%
df[df['Units Sold'] > 9990]
# Out:
#                                  Region         Country        Item Type  \
# 1508                             Europe  United Kingdom    Personal Care
# 1985                             Europe         Ireland          Clothes
# 2564  Central America and the Caribbean        Dominica        Baby Food
# 3378                               Asia        Thailand           Fruits
# 3923                             Europe        Portugal  Office Supplies
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 1508       Offline              H  12/23/2013  387098824   1/4/2014
# 1985        Online              C   10/2/2012  261187350  10/3/2012
# 2564        Online              C   6/26/2011  446438729   8/6/2011
# 3378        Online              M  11/30/2011  844245946   1/1/2012
# 3923       Offline              C   2/17/2012  775849616   3/5/2012
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %% [markdown]
# Select rows where 'Units Sold' is greater than 9990 with selected column only

# %%
df.loc[df['Units Sold'] > 9990,'Order Date']
# Out:
# 1508    12/23/2013
# 1985     10/2/2012
# 2564     6/26/2011
# 3378    11/30/2011
# 3923     2/17/2012
# Name: Order Date, dtype: object

# %% [markdown]
# Select rows where 'Units Sold' is greater than 9990 with selected "columns" only

# %%
df.loc[(df['Units Sold'] > 9990),('Order Date','Country')]
# Out:
#       Order Date         Country
# 1508  12/23/2013  United Kingdom
# 1985   10/2/2012         Ireland
# 2564   6/26/2011        Dominica
# 3378  11/30/2011        Thailand
# 3923   2/17/2012        Portugal

# %% [markdown]
# loc[] and iloc[] for Label-based and Positional Indexing

# %%
df.loc[0:10, ['Region', 'Country', 'Total Revenue']]
# Out:
#                                Region                         Country  \
# 0   Central America and the Caribbean            Antigua and Barbuda
# 1   Central America and the Caribbean                          Panama
# 2                              Europe                  Czech Republic
# 3                                Asia                     North Korea
# 4                                Asia                       Sri Lanka
# 5        Middle East and North Africa                         Morocco
# 6               Australia and Oceania  Federated States of Micronesia
# 7                              Europe          Bosnia and Herzegovina
# 8        Middle East and North Africa                     Afghanistan
# 9                  Sub-Saharan Africa                        Ethiopia
# 10       Middle East and North Africa                          Turkey
#
#     Total Revenue
# 0       140914.56
# 1       330640.86
# 2       226716.10
# 3      1854591.20
# 4      1150758.36
# ...

# %% [markdown]
# iloc[] (Positional Indexing):

# %%
df.iloc[0:10, 0:3]
# Out:
#                               Region                         Country  \
# 0  Central America and the Caribbean            Antigua and Barbuda
# 1  Central America and the Caribbean                          Panama
# 2                             Europe                  Czech Republic
# 3                               Asia                     North Korea
# 4                               Asia                       Sri Lanka
# 5       Middle East and North Africa                         Morocco
# 6              Australia and Oceania  Federated States of Micronesia
# 7                             Europe          Bosnia and Herzegovina
# 8       Middle East and North Africa                     Afghanistan
# 9                 Sub-Saharan Africa                        Ethiopia
#
#        Item Type
# 0      Baby Food
# 1         Snacks
# 2      Beverages
# 3         Cereal
# 4         Snacks
# 5  Personal Care
# 6        Clothes
# 7        Clothes
# 8        Clothes
# 9      Baby Food

# %% [markdown]
# ###  Conditional Selection

# %% [markdown]
# Using & (AND Condition):

# %%
df.loc[(df['Sales Channel'] == 'Online') & (df['Units Sold'] > 9990)]
# Out:
#                                  Region   Country  Item Type Sales Channel  \
# 1985                             Europe   Ireland    Clothes        Online
# 2564  Central America and the Caribbean  Dominica  Baby Food        Online
# 3378                               Asia  Thailand     Fruits        Online
#
#      Order Priority  Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 1985              C   10/2/2012  261187350  10/3/2012        9996      109.28
# 2564              C   6/26/2011  446438729   8/6/2011        9996      255.28
# 3378              M  11/30/2011  844245946   1/1/2012        9991        9.33
#
#       Unit Cost  Total Revenue  Total Cost  Total Profit
# 1985      35.84     1092362.88   358256.64     734106.24
# 2564     159.42     2551778.88  1593562.32     958216.56
# 3378       6.92       93216.03    69137.72      24078.31

# %% [markdown]
# Using | (OR Condition)

# %%
df[(df['Country'] == 'USA') | (df['Units Sold'] < 10)]
# Out:
#                                  Region                   Country  \
# 582                                Asia                    Brunei
# 664                       North America  United States of America
# 1046                             Europe                  Bulgaria
# 1405                 Sub-Saharan Africa                    Rwanda
# 1435              Australia and Oceania                East Timor
# 2244                             Europe    Bosnia and Herzegovina
# 3284  Central America and the Caribbean    Saint Kitts and Nevis
# 3562                 Sub-Saharan Africa  Central African Republic
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 582         Baby Food        Online              C   4/19/2012  918961560
# 664            Fruits        Online              M   12/9/2014  158660447
# 1046        Household        Online              C   3/21/2014  129902875
# 1405          Clothes        Online              M  10/23/2013  410077846
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## delete rows

# %%
df
# Out:
#                                  Region               Country  Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean                Panama     Snacks
# 2                                Europe        Czech Republic  Beverages
# 3                                  Asia           North Korea     Cereal
# 4                                  Asia             Sri Lanka     Snacks
# ...                                 ...                   ...        ...
# 4994                 Sub-Saharan Africa               Liberia  Cosmetics
# 4995              Australia and Oceania           New Zealand  Household
# 4996       Middle East and North Africa            Azerbaijan    Clothes
# 4997                               Asia               Myanmar  Baby Food
# 4998                             Europe               Finland    Clothes
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %% [markdown]
# ## converting datatype

# %%
df[['Order ID',"Units Sold"]]=df[['Order ID','Units Sold']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          4999 non-null   object
#  1   Country         4999 non-null   object
#  2   Item Type       4999 non-null   object
#  3   Sales Channel   4999 non-null   object
#  4   Order Priority  4999 non-null   object
#  5   Order Date      4999 non-null   object
#  6   Order ID        4999 non-null   int64
#  7   Ship Date       4999 non-null   object
#  8   Units Sold      4999 non-null   int64
#  9   Unit Price      4999 non-null   float64
#  10  Unit Cost       4999 non-null   float64
#  11  Total Revenue   4999 non-null   float64
#  12  Total Cost      4999 non-null   float64
#  13  Total Profit    4999 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 546.9+ KB

# %% [markdown]
# ###  Indexing Rows Using set_index()

# %%
# df.set_index('Order ID', inplace=True)

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# ### Slicing Rows

# %%
df[5:11]
# Out:
#                           Region                         Country  \
# 5   Middle East and North Africa                         Morocco
# 6          Australia and Oceania  Federated States of Micronesia
# 7                         Europe          Bosnia and Herzegovina
# 8   Middle East and North Africa                     Afghanistan
# 9             Sub-Saharan Africa                        Ethiopia
# 10  Middle East and North Africa                          Turkey
#
#           Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 5     Personal Care       Offline              L   11/8/2010  412882792
# 6           Clothes       Offline              H   3/28/2011  932776868
# 7           Clothes        Online              M  10/14/2013  919133651
# 8           Clothes       Offline              M   8/27/2016  579814469
# 9         Baby Food        Online              M   4/13/2015  192993152
# 10  Office Supplies       Offline              C   9/25/2013  557156026
#
# ...

# %% [markdown]
# ### Selecting Specific Columns After a Filter

# %%
df[df['Region'] == 'Asia'][['Country', 'Item Type', 'Total Revenue']]
# Out:
#           Country        Item Type  Total Revenue
# 3     North Korea           Cereal     1854591.20
# 4       Sri Lanka           Snacks     1150758.36
# 12       Malaysia           Cereal     2008043.40
# 42           Laos             Meat     2329676.58
# 43     Kyrgyzstan           Snacks       12816.72
# ...           ...              ...            ...
# 4984     Cambodia       Vegetables      551688.86
# 4985         Laos        Cosmetics     2303169.60
# 4986    Sri Lanka  Office Supplies      268298.52
# 4989     Thailand           Snacks      846361.26
# 4997      Myanmar        Baby Food     1328477.12
#
# [719 rows x 3 columns]

# %% [markdown]
# #  Creating a Multi-Index

# %% [markdown]
# Setting Multi-Index on Columns 'Region' and 'Country'

# %%
dg=df.set_index(['Region', 'Country'])

# %%
dg
# Out:
#                                                         Item Type  \
# Region                            Country
# Central America and the Caribbean Antigua and Barbuda   Baby Food
#                                   Panama                   Snacks
# Europe                            Czech Republic        Beverages
# Asia                              North Korea              Cereal
#                                   Sri Lanka                Snacks
# ...                                                           ...
# Sub-Saharan Africa                Liberia               Cosmetics
# Australia and Oceania             New Zealand           Household
# Middle East and North Africa      Azerbaijan              Clothes
# Asia                              Myanmar               Baby Food
# Europe                            Finland                 Clothes
#
#                                                        Sales Channel  \
# Region                            Country
# ...

# %% [markdown]
# ###  Accessing Data with Multi-Index

# %%
dg.loc[('Asia', 'China')].head()
# Out:
# C:\Users\rav\AppData\Local\Temp\ipykernel_20472\2604089139.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dg.loc[('Asia', 'China')].head()
#                 Item Type Sales Channel Order Priority Order Date   Order ID  \
# Region Country
# Asia   China    Cosmetics       Offline              H  4/15/2015  834844052
#        China    Household        Online              L  3/29/2012  931632745
#        China      Clothes       Offline              C  9/26/2016  833519256
#        China         Meat        Online              H  2/17/2014  101010978
#        China       Cereal        Online              L  7/26/2012  894569337
#
#                  Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Region Country
# Asia   China     5/20/2015        7762      437.20     263.33     3393546.40
#        China      5/2/2012        9687      668.27     502.54     6473531.49
# ...

# %% [markdown]
# ### Sorting by Multi-Index

# %% [markdown]
# Sorting based on the multi-index is possible using the sort_index() method.

# %%
dg=dg.sort_index()

# %%
dg
# Out:
#                                      Item Type Sales Channel Order Priority  \
# Region             Country
# Asia               Bangladesh        Household       Offline              C
#                    Bangladesh           Fruits        Online              L
#                    Bangladesh          Clothes        Online              C
#                    Bangladesh           Snacks        Online              H
#                    Bangladesh  Office Supplies       Offline              M
# ...                                        ...           ...            ...
# Sub-Saharan Africa Zimbabwe             Cereal       Offline              L
#                    Zimbabwe          Beverages       Offline              H
#                    Zimbabwe             Cereal        Online              L
#                    Zimbabwe            Clothes       Offline              M
#                    Zimbabwe               Meat       Offline              M
#
# ...

# %% [markdown]
# ### Cross-section (xs) for Slicing Multi-Index
# The xs() method allows you to slice data along a particular level of the multi-index.

# %%
df_cross = dg.xs('China', level='Country')
df_cross
# Out:
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# Region
# Asia        Cosmetics       Offline              H   4/15/2015  834844052
# Asia        Household        Online              L   3/29/2012  931632745
# Asia          Clothes       Offline              C   9/26/2016  833519256
# Asia             Meat        Online              H   2/17/2014  101010978
# Asia           Cereal        Online              L   7/26/2012  894569337
# Asia             Meat        Online              C   1/30/2015  916976726
# Asia        Household        Online              H  11/30/2010  672215068
# Asia        Household       Offline              C   12/5/2015  863480603
# Asia        Beverages       Offline              C    5/4/2016  501834714
# Asia           Cereal        Online              C  10/12/2012  487615144
# Asia          Clothes        Online              L  12/19/2012  723061597
# Asia        Beverages        Online              M   6/26/2010  189315736
# ...

# %% [markdown]
# ### Aggregating Data with Multi-Index
# You can perform operations like groupby on multi-indexed DataFrames, which allows you to aggregate data at different levels

# %%
dg.groupby('Region')['Units Sold'].sum()
# Out:
# Region
# Asia                                 3620036
# Australia and Oceania                2111786
# Central America and the Caribbean    2698776
# Europe                               6582322
# Middle East and North Africa         3013431
# North America                         484760
# Sub-Saharan Africa                   6639930
# Name: Units Sold, dtype: int64

# %% [markdown]
# ### Resetting the Multi-Index
# To remove the multi-index and return to a flat structure, use reset_index().

# %%
dg = dg.reset_index()
dg
# Out:
#                   Region     Country        Item Type Sales Channel  \
# 0                   Asia  Bangladesh        Household       Offline
# 1                   Asia  Bangladesh           Fruits        Online
# 2                   Asia  Bangladesh          Clothes        Online
# 3                   Asia  Bangladesh           Snacks        Online
# 4                   Asia  Bangladesh  Office Supplies       Offline
# ...                  ...         ...              ...           ...
# 4994  Sub-Saharan Africa    Zimbabwe           Cereal       Offline
# 4995  Sub-Saharan Africa    Zimbabwe        Beverages       Offline
# 4996  Sub-Saharan Africa    Zimbabwe           Cereal        Online
# 4997  Sub-Saharan Africa    Zimbabwe          Clothes       Offline
# 4998  Sub-Saharan Africa    Zimbabwe             Meat       Offline
#
#      Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %% [markdown]
# same

# %%
dg.loc[(dg['Region']=='Asia') & ((dg['Country']=="China") | (dg['Country']=='India')) ]
# Out:
#     Region Country        Item Type Sales Channel Order Priority  Order Date  \
# 112   Asia   China        Cosmetics       Offline              H   4/15/2015
# 113   Asia   China        Household        Online              L   3/29/2012
# 114   Asia   China          Clothes       Offline              C   9/26/2016
# 115   Asia   China             Meat        Online              H   2/17/2014
# 116   Asia   China           Cereal        Online              L   7/26/2012
# 117   Asia   China             Meat        Online              C   1/30/2015
# 118   Asia   China        Household        Online              H  11/30/2010
# 119   Asia   China        Household       Offline              C   12/5/2015
# 120   Asia   China        Beverages       Offline              C    5/4/2016
# 121   Asia   China           Cereal        Online              C  10/12/2012
# 122   Asia   China          Clothes        Online              L  12/19/2012
# ...

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
plt.figure(figsize=(10, 5))
df.groupby(df['Ship Date'].dt.year)['Units Sold'].sum().plot(kind='bar')
plt.title(' per year sale')
plt.xlabel('year')
plt.ylabel('unit sold')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10, 5))
df.groupby(df['Region'])['Units Sold'].sum().plot(kind='bar')
plt.title('Region sale')
plt.xlabel('Region')
plt.ylabel('unit sold')
plt.xticks(rotation=25, ha='right')
plt.show()

# %% [markdown]
# ## Sales Comparison Between Two Regions per Year

# %%
df['Year'] = df['Ship Date'].dt.year

df_filtered = df[df['Region'].isin(['Asia', 'Europe'])]

sales_per_year = df_filtered.groupby(['Region', 'Year'])['Total Revenue'].sum().unstack()

sales_per_year.T.plot(kind='bar', figsize=(10, 6))

plt.title('Sales Comparison Between Two Regions per Year')
plt.xlabel('Year')
plt.ylabel('Total Revenue')
plt.legend(title='Region')
plt.tight_layout()
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Filtering Based on String Patterns

# %%
df[df['Country'].str.contains('United')]
# Out:
#                             Region                   Country        Item Type  \
# 30    Middle East and North Africa      United Arab Emirates        Cosmetics
# 104                         Europe            United Kingdom        Beverages
# 132   Middle East and North Africa      United Arab Emirates        Beverages
# 160                  North America  United States of America  Office Supplies
# 329                  North America  United States of America           Cereal
# ...                            ...                       ...              ...
# 4533                 North America  United States of America  Office Supplies
# 4849                        Europe            United Kingdom        Baby Food
# 4883                 North America  United States of America           Snacks
# 4928  Middle East and North Africa      United Arab Emirates        Household
# 4988  Middle East and North Africa      United Arab Emirates        Household
#
# ...

# %% [markdown]
# ### Filtering with .isin()
# The .isin() method allows you to filter rows where a column’s value is present in a list of values.

# %%
df[df['Country'].isin(['USA', 'Canada'])]
# Out:
#              Region Country        Item Type Sales Channel Order Priority  \
# 615   North America  Canada          Clothes       Offline              H
# 729   North America  Canada        Household       Offline              M
# 879   North America  Canada        Cosmetics        Online              C
# 966   North America  Canada        Household        Online              H
# 1269  North America  Canada           Snacks       Offline              M
# 1892  North America  Canada        Household        Online              M
# 1942  North America  Canada        Cosmetics        Online              C
# 2191  North America  Canada        Cosmetics       Offline              L
# 2704  North America  Canada           Fruits       Offline              M
# 2791  North America  Canada  Office Supplies        Online              L
# 2842  North America  Canada        Household        Online              C
# 3040  North America  Canada           Snacks       Offline              M
# ...

# %% [markdown]
# ### Filtering with .query() Method
# Pandas provides a .query() method to filter DataFrames in a more SQL-like syntax. This can make more complex filters easier to read.

# %%
df.query("`Sales Channel` == 'Online' and `Total Profit` > 1700000")
# Out:
#                   Region                           Country  Item Type  \
# 896   Sub-Saharan Africa                             Benin  Cosmetics
# 2290  Sub-Saharan Africa  Democratic Republic of the Congo  Cosmetics
# 2471  Sub-Saharan Africa                      Burkina Faso  Cosmetics
# 2899       North America                         Greenland  Cosmetics
# 3236              Europe                           Andorra  Cosmetics
# 4599  Sub-Saharan Africa                       South Sudan  Cosmetics
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# 896         Online              M  4/27/2012  813325440 2012-05-15
# 2290        Online              H   9/5/2013  523857152 2013-10-09
# 2471        Online              H  2/16/2011  980396163 2011-02-24
# 2899        Online              M  2/12/2013  873847663 2013-03-10
# 3236        Online              H  4/10/2012  291160714 2012-05-26
# 4599        Online              H   1/3/2014  128990066 2014-01-24
#
# ...

# %% [markdown]
# ### Filtering with .between()
# The .between() method can be used to filter data between two values (inclusive).

# %%
df[df['Units Sold'].between(480, 500)]
# Out:
#                                  Region       Country      Item Type  \
# 94                                 Asia     Sri Lanka         Cereal
# 824                              Europe    San Marino     Vegetables
# 878                  Sub-Saharan Africa       Burundi         Fruits
# 1119  Central America and the Caribbean        Belize  Personal Care
# 1256                             Europe      Slovenia      Baby Food
# 2939                             Europe        France         Fruits
# 2992                             Europe        Greece         Snacks
# 3076                 Sub-Saharan Africa  Burkina Faso      Baby Food
# 4364                             Europe    Luxembourg           Meat
# 4806                             Europe      Slovakia      Cosmetics
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 94          Online              C   2/24/2015  743410336 2015-03-20
# 824        Offline              M   1/22/2016  560389268 2016-02-22
# ...

# %%
df.groupby(['Region'])["Units Sold"].max()
# Out:
# Region
# Asia                                 9991
# Australia and Oceania                9990
# Central America and the Caribbean    9996
# Europe                               9999
# Middle East and North Africa         9881
# North America                        9898
# Sub-Saharan Africa                   9984
# Name: Units Sold, dtype: int64

# %% [markdown]
# ### Filtering with .notnull() or .isnull()
# You can filter rows based on whether a column has null (NaN) or non-null values.

# %%
df['Total Revenue'][4990:4998]=None
# Out:
# C:\Users\rav\AppData\Local\Temp\ipykernel_20472\4238673266.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Total Revenue'][4990:4998]=None
# ...

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     8
# Total Cost        0
# Total Profit      0
# Year              0
# dtype: int64

# %%
df[df['Total Revenue'].isnull()]
# Out:
#                             Region      Country  Item Type Sales Channel  \
# 4990                        Europe      Ukraine     Cereal       Offline
# 4991                        Europe      Armenia       Meat       Offline
# 4992  Middle East and North Africa         Iran    Clothes       Offline
# 4993                        Europe      Denmark    Clothes       Offline
# 4994            Sub-Saharan Africa      Liberia  Cosmetics       Offline
# 4995         Australia and Oceania  New Zealand  Household       Offline
# 4996  Middle East and North Africa   Azerbaijan    Clothes       Offline
# 4997                          Asia      Myanmar  Baby Food       Offline
#
#      Order Priority  Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 4990              L   4/14/2014  559183347 2014-05-21        3633      205.70
# 4991              M   11/9/2015  781416594 2015-12-23        7390      421.89
# ...

# %%
import missingno as msno

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Handling Missing Data in GroupBy
# You can fill missing values before or after grouping to avoid errors in the aggregation.
#
# Example: Fill Missing Values and Group

# %%
# Fill missing 'Units Sold' with 0, then group and sum
df['Total Revenue'].fillna(df['Units Sold']*df['Unit Price']-df['Units Sold']*df['Unit Cost'], inplace=True)
df.groupby('Region')['Total Revenue'].sum()
# Out:
# C:\Users\rav\AppData\Local\Temp\ipykernel_20472\3387041866.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Revenue'].fillna(df['Units Sold']*df['Unit Price']-df['Units Sold']*df['Unit Cost'], inplace=True)
# Region
# Asia                                 9.194475e+08
# Australia and Oceania                5.846981e+08
# Central America and the Caribbean    6.849763e+08
# Europe                               1.700248e+09
# Middle East and North Africa         7.667807e+08
# ...

# %%
df
# Out:
#                                  Region               Country  Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean                Panama     Snacks
# 2                                Europe        Czech Republic  Beverages
# 3                                  Asia           North Korea     Cereal
# 4                                  Asia             Sri Lanka     Snacks
# ...                                 ...                   ...        ...
# 4994                 Sub-Saharan Africa               Liberia  Cosmetics
# 4995              Australia and Oceania           New Zealand  Household
# 4996       Middle East and North Africa            Azerbaijan    Clothes
# 4997                               Asia               Myanmar  Baby Food
# 4998                             Europe               Finland    Clothes
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# ...

# %%
# Group by 'Region' and 'Country' and sum 'Units Sold'
df.groupby(['Region', 'Country'])['Units Sold'].sum()
# Out:
# Region              Country
# Asia                Bangladesh     92850
#                     Bhutan        150222
#                     Brunei        139144
#                     Cambodia      129218
#                     China         116042
#                                    ...
# Sub-Saharan Africa  The Gambia     92190
#                     Togo          140939
#                     Uganda        113153
#                     Zambia        139635
#                     Zimbabwe       93906
# Name: Units Sold, Length: 185, dtype: int64

# %% [markdown]
# ### Multiple Aggregations with agg()
# You can use agg() to apply multiple aggregation functions to one or more columns.
#
# Example: Group by 'Sales Channel' and Calculate Multiple Aggregations

# %%
mk=df.groupby('Item Type').agg({
    'Total Profit': 'sum',
    'Unit Price': "mean",
    'Units Sold': 'sum'
})

# %%
mk['Total Profit']=mk['Total Profit'].apply( lambda x: f'{x/1000000:.1f}M')

# %%
mk.head()
# Out:
#           Total Profit  Unit Price  Units Sold
# Item Type
# Baby Food       218.1M      255.28     2274921
# Beverages        34.6M       47.45     2208169
# Cereal          172.7M      205.70     1949601
# Clothes         145.7M      109.28     1983445
# Cosmetics       372.4M      437.20     2141909

# %%
df.groupby('Item Type')['Total Profit'].agg(['sum', 'mean', 'max'])
# Out:
#                           sum           mean         max
# Item Type
# Baby Food        2.180739e+08  490053.768674   958216.56
# Beverages        3.457993e+07   77360.014631   156443.40
# Cereal           1.727152e+08  448610.785948   883330.89
# Clothes          1.456642e+08  377368.395855   734106.24
# Cosmetics        3.724137e+08  878334.240165  1726007.49
# Fruits           5.642010e+06   12621.946376    24078.31
# Household        3.479067e+08  820534.702217  1654814.05
# Meat             1.087485e+08  272552.552381   570570.00
# Office Supplies  2.660880e+08  633542.940476  1262121.25
# Personal Care    5.350047e+07  128916.792048   250574.94
# Snacks           1.059281e+08  266150.943467   550517.76
# Vegetables       1.318079e+08  322268.617115   626060.21

# %%
# Group by 'Country' and filter groups where total 'Units Sold' > 1000
df.groupby('Country').filter(lambda x: x['Units Sold'].sum()> 200000)
# Out:
#                                  Region    Country        Item Type  \
# 90    Central America and the Caribbean    Grenada           Cereal
# 168   Central America and the Caribbean    Grenada             Meat
# 184   Central America and the Caribbean    Grenada       Vegetables
# 267                              Europe  Macedonia        Cosmetics
# 317                              Europe  Macedonia    Personal Care
# ...                                 ...        ...              ...
# 4595                             Europe  Macedonia        Beverages
# 4825  Central America and the Caribbean    Grenada        Beverages
# 4890  Central America and the Caribbean    Grenada        Beverages
# 4906                             Europe  Macedonia        Household
# 4964  Central America and the Caribbean    Grenada  Office Supplies
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 90          Online              H   1/17/2016  584436452 2016-02-09
# ...

# %% [markdown]
#  Group by 'Region' and apply a custom function that returns the difference between 'Total Profit' and 'Total Cost'

# %%
df.groupby('Region').apply(lambda x: x['Total Profit'] - x['Total Cost'])
# Out:
# C:\Users\rav\AppData\Local\Temp\ipykernel_20472\3770389734.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Region').apply(lambda x: x['Total Profit'] - x['Total Cost'])
# Region
# Asia                3       -257136.32
#                     4       -319026.60
#                     12      -278412.24
#                     42     -1697959.78
#                     43        -3553.20
#                                ...
# Sub-Saharan Africa  4976    -265121.92
#                     4977   -2889052.66
#                     4979    -249866.10
#                     4981    -373989.98
#                     4994    -733124.70
# Length: 4999, dtype: float64

# %% [markdown]
# ### GroupBy and Pivoting
# After grouping, you can reshape the data using pivot_table() for better summaries.
#
# Example: Group by 'Region' and 'Item Type' and Pivot the Data

# %%
df.pivot_table(values='Units Sold', index='Region', columns='Item Type', aggfunc='sum')
# Out:
# Item Type                          Baby Food  Beverages  Cereal  Clothes  \
# Region
# Asia                                  337230     336822  302066   300491
# Australia and Oceania                 218174     212003  187394   152696
# Central America and the Caribbean     238762     218889  244281   205354
# Europe                                562706     613133  465685   591385
# Middle East and North Africa          272935     226452  252472   267226
# North America                          26417      81114   23648    20012
# Sub-Saharan Africa                    618697     519756  474055   446281
#
# Item Type                          Cosmetics  Fruits  Household    Meat  \
# Region
# Asia                                  288409  387730     352254  240247
# Australia and Oceania                 224028  138460     155023  154374
# Central America and the Caribbean     196744  241847     214100  242367
# Europe                                533291  591672     440249  533376
# ...

# %%
# Apply a lambda function row-wise to calculate profit margin (Total Profit / Total Revenue)
df['Profit Margin'] = df.apply(lambda row: row['Total Profit']/row['Total Revenue'],axis=1)

# %%
df['Total Profit']/df['Total Revenue']
# Out:
# 0       0.375509
# 1       0.361384
# 2       0.330032
# 3       0.430676
# 4       0.361384
#           ...
# 4994    1.000000
# 4995    1.000000
# 4996    1.000000
# 4997    1.000000
# 4998    0.672035
# Length: 4999, dtype: float64

# %%
plt.figure(figsize=(10, 5))
df.groupby(['Item Type'])['Profit Margin'].mean().plot(kind='bar')
plt.title('average Profit Margin per Item Type')
plt.xlabel('Item Type')
plt.ylabel('Profit Margin')
plt.xticks(rotation=25, ha='right')
plt.show()

# %%
# Map a lambda function to transform 'Order Priority' from string to numerical values
df['Priority Level'] = df['Order Priority'].map(lambda x: 1 if x == 'H' else 0)

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544 2014-01-11         552
# 1       Offline              C    7/5/2010  301644504 2010-07-26        2167
# 2       Offline              C   9/12/2011  478051030 2011-09-29        4778
# 3       Offline              L   5/13/2010  892599952 2010-06-15        9016
# 4       Offline              C   7/20/2015  571902596 2015-07-27        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  Year  \
# ...

# %%
df[df['Order Priority']=='H']
# Out:
#                                  Region                         Country  \
# 6                 Australia and Oceania  Federated States of Micronesia
# 13    Central America and the Caribbean                     Saint Lucia
# 15         Middle East and North Africa                         Lebanon
# 25    Central America and the Caribbean                            Cuba
# 30         Middle East and North Africa            United Arab Emirates
# ...                                 ...                             ...
# 4981                 Sub-Saharan Africa                         Eritrea
# 4982       Middle East and North Africa                            Iran
# 4988       Middle East and North Africa            United Arab Emirates
# 4993                             Europe                         Denmark
# 4997                               Asia                         Myanmar
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
# Apply lambda to add a bonus if 'Total Profit' > 1000
df.apply(lambda x: x['Total Profit'] + 100 if x['Total Profit'] > 1000 else x['Total Profit'], axis=1)
# Out:
# 0         53014.72
# 1        119588.38
# 2         74923.48
# 3        798827.44
# 4        415965.88
#            ...
# 4994    1424964.65
# 4995     879297.65
# 4996      79194.88
# 4997     498955.44
# 4998     691170.40
# Length: 4999, dtype: float64

# %% [markdown]
# ### Column-Wise Transformation with apply()
# You can transform data on a column-by-column basis using apply().
#
# Example: Apply a Function to Normalize Data

# %%
# Normalize the 'Total Revenue' column
df['Normalized Revenue'] = df['Total Revenue'].apply(lambda x: (x - df['Total Revenue'].min()) / (df['Total Revenue'].max() - df['Total Revenue'].min()))
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544 2014-01-11         552
# 1       Offline              C    7/5/2010  301644504 2010-07-26        2167
# 2       Offline              C   9/12/2011  478051030 2011-09-29        4778
# 3       Offline              L   5/13/2010  892599952 2010-06-15        9016
# 4       Offline              C   7/20/2015  571902596 2015-07-27        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  Year  \
# ...
